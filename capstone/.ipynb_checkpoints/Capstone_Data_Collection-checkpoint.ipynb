# %% [markdown]
# # Capstone: Data Collection

# %% [markdown]
# ## Datasets:
# - 10-K from SEC
# - Stock price from Yahoo Finance
# - list of S&P500 tickers

# %%
# importing libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# web scraping libraries
import requests
import time
import random
from bs4 import BeautifulSoup
import re

# library used to scrape the SEC for 10-k annual reports
from edgar import Company, TXTML, Edgar

#library for historical stock prices
import yfinance as yf
from datetime import timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## Data collection

# %%
# loading dataset of S&P500 companies
# source: https://github.com/datasets/s-and-p-500-companies/blob/master/data/constituents.csv
df_sp = pd.read_csv('./datasets/S&P500.csv')

# %%
df_sp.head()
# Out:
#   Symbol                 Name       Sector
# 0    MMM           3M Company  Industrials
# 1    AOS      A.O. Smith Corp  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV          AbbVie Inc.  Health Care
# 4   ABMD          ABIOMED Inc  Health Care

# %%
df_sp.columns = [x.lower() for x in df_sp.columns]

# %%
df_sp.head()
# Out:
#   symbol                 name       sector
# 0    MMM           3M Company  Industrials
# 1    AOS      A.O. Smith Corp  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV          AbbVie Inc.  Health Care
# 4   ABMD          ABIOMED Inc  Health Care

# %%
len(df_sp)
# Out:
# 505

# %%
# Checking for Companies that issue different classes of shares
# removing them as their 10-k would be the same
df_sp[df_sp['name'].str.contains('Class')]
# Out:
#     symbol                       name                  sector
# 24   GOOGL    Alphabet Inc. (Class A)  Communication Services
# 25    GOOG    Alphabet Inc. (Class C)  Communication Services
# 144  DISCA   Discovery Inc. (Class A)  Communication Services
# 145  DISCK   Discovery Inc. (Class C)  Communication Services
# 200   FOXA  Fox Corporation (Class A)  Communication Services
# 201    FOX  Fox Corporation (Class B)  Communication Services
# 333   NWSA         News Corp. Class A  Communication Services
# 334    NWS         News Corp. Class B  Communication Services
# 457    UAA     Under Armour (Class A)  Consumer Discretionary
# 458     UA     Under Armour (Class C)  Consumer Discretionary

# %%
# Rows to drop
# the SEC is not consistent with the ticker names,
rows_to_drop = [24,145,201,334,458]

# %%
# dropping in place
df_sp.drop(rows_to_drop, inplace=True)

# %%
# Reconciling the difference in length
drop = df_sp[(df_sp['name']=='Berkshire Hathaway') |
      (df_sp['name']=='Brown-Forman Corp.') | 
      (df_sp['name']=='CBRE Group') | 
      (df_sp['name']=='Evergy') | 
      (df_sp['name']=='First Republic Bank') | 
      (df_sp['name']=='ViacomCBS') |
      (df_sp['name']=='Ingersoll Rand')]

# %%
# index of rows to drop
drop.index
# Out:
# Int64Index([66, 78, 90, 175, 189, 246, 474], dtype='int64')

# %%
#remove companies not in the list
df_sp.drop(drop.index, inplace=True)

# %%
df_sp.shape
# Out:
# (493, 3)

# %%
# Scraping through the sec to get the CIK and name of each company
# using the ticker. names do not match the proper sec database names

list_name = []
list_cik = []

for x in df_sp['symbol']:
    url = 'https://www.sec.gov/cgi-bin/browse-edgar?CIK=' + str(x) + '&type=10-K&dateb=&owner=include&count=40'
    res = requests.get(url, headers={'User-agent': 'Pony Inc 1.0'})
    res.status_code
    soup = BeautifulSoup(res.text, 'lxml')    
            
    for row in soup.find_all('span', {'class':'companyName'}):
        list_name.append(row.text.split(' CIK#: ')[0])
        list_cik.append(row.text.split(' CIK#: ')[1][:10])

# %%
# Reconciling the difference in length
# Due to companies delisting or merging etc.
print(len(df_sp))
print(len(list_name))
print(len(list_cik))
# Out:
# 493
# 493
# 493

# %%
df_sp.shape
# Out:
# (493, 3)

# %%
# appending list_name and list_cik to df_sp
df_sp['name_clean'] = list_name
df_sp['cik'] = list_cik

df_sp.head()
# Out:
#   symbol                 name       sector           name_clean         cik
# 0    MMM           3M Company  Industrials                3M CO  0000066740
# 1    AOS      A.O. Smith Corp  Industrials       SMITH A O CORP  0000091142
# 2    ABT  Abbott Laboratories  Health Care  ABBOTT LABORATORIES  0000001800
# 3   ABBV          AbbVie Inc.  Health Care          AbbVie Inc.  0001551152
# 4   ABMD          ABIOMED Inc  Health Care          ABIOMED INC  0000815094

# %%
#checking the shape of the new df_sp
df_sp.shape
# Out:
# (493, 5)

# %% [markdown]
# ## Scraping the dates of each 10-K

# %%
#Scraping through the sec to get each date of 10-K filed for each company
ticker = []
dates = []


for x in df_sp['symbol']:
    url = 'https://www.sec.gov/cgi-bin/browse-edgar?CIK=' + str(x) + '&type=10-K&dateb=&owner=include&count=40'
    res = requests.get(url, headers={'User-agent': 'Pony Inc 1.0'})
    res.status_code
    soup = BeautifulSoup(res.text, 'lxml')
    
    table = soup.find('table', {'class':'tableFile2'})
    rows= table.find_all('tr')[1:]
    i = 0
    for row in rows:
        if len(rows) < 6:
            break
        elif len(rows) >= 6:    
            cells = row.find_all('td')
            filing = {}

            if i < 6:
                for cell in cells[3]:
                    ticker.append(x)
                    dates.append(cell)
                    i += 1
            elif i > 6:
                break

# %%
# getting rid of companies without 6 annual reports on the SEC
df_sp = df_sp[df_sp['symbol'].isin(np.unique(ticker))]

# %%
#checking the shape of df_sp
df_sp.shape
# Out:
# (468, 5)

# %%
#checking the first few rows of df_sp
df_sp.head()
# Out:
#   symbol                 name       sector           name_clean         cik
# 0    MMM           3M Company  Industrials                3M CO  0000066740
# 1    AOS      A.O. Smith Corp  Industrials       SMITH A O CORP  0000091142
# 2    ABT  Abbott Laboratories  Health Care  ABBOTT LABORATORIES  0000001800
# 3   ABBV          AbbVie Inc.  Health Care          AbbVie Inc.  0001551152
# 4   ABMD          ABIOMED Inc  Health Care          ABIOMED INC  0000815094

# %%
#checking first 10 tickers
ticker[:10]
# Out:
# ['MMM', 'MMM', 'MMM', 'MMM', 'MMM', 'MMM', 'AOS', 'AOS', 'AOS', 'AOS']

# %%
#checking first 10 dates
dates[:10]
# Out:
# ['2020-02-06',
#  '2019-02-07',
#  '2018-02-08',
#  '2017-02-09',
#  '2016-02-11',
#  '2015-02-12',
#  '2020-02-24',
#  '2019-02-15',
#  '2018-02-16',
#  '2017-02-17']

# %%
df_sp_1 = df_sp[:int(len(df_sp)/2)]
df_sp_2 = df_sp[int(len(df_sp)/2):]

# %% [markdown]
# ## Scraping 10-K reports from the SEC

# %%
#scraping the SEC for the 10-K of each company
reports_10K = []
reports_name = []

for name, cik in zip(df_sp_1['name_clean'], df_sp_1['cik']):
    company = Company(name, cik)
    docs = company.get_10Ks(no_of_documents=6)
    #appending a blank row because the latest 2020 report will not be used
    reports_10K.append('')
    reports_name.append(name)
    
    # generate a random sleep duration to look more 'natural'
    sleep_duration = random.randint(15,30)
    print(sleep_duration)
    time.sleep(sleep_duration) #program sleeps for the sleep_duration
    
    for doc in docs[1:]:
        text = TXTML.parse_full_10K(doc)    
        reports_10K.append(text)
        reports_name.append(name)
        print(name)
# Out:
# 24
# 3M CO
# 3M CO
# 3M CO
# 3M CO
# 3M CO
# 20
# SMITH A O CORP
# SMITH A O CORP
# SMITH A O CORP
# SMITH A O CORP
# SMITH A O CORP
# 26
# ABBOTT LABORATORIES
# ABBOTT LABORATORIES
# ABBOTT LABORATORIES
# ABBOTT LABORATORIES
# ABBOTT LABORATORIES
# 18
# AbbVie Inc.
# AbbVie Inc.
# AbbVie Inc.
# AbbVie Inc.
# AbbVie Inc.
# 24
# ABIOMED INC
# ABIOMED INC
# ABIOMED INC
# ABIOMED INC
# ABIOMED INC
# 19
# Accenture plc
# Accenture plc
# Accenture plc
# Accenture plc
# Accenture plc
# 26
# Activision Blizzard, Inc.
# Activision Blizzard, Inc.
# Activision Blizzard, Inc.
# Activision Blizzard, Inc.
# Activision Blizzard, Inc.
# 28
# ADOBE INC.
# ADOBE INC.
# ADOBE INC.
# ADOBE INC.
# ADOBE INC.
# 18
# ADVANCE AUTO PARTS INC
# ADVANCE AUTO PARTS INC
# ADVANCE AUTO PARTS INC
# ADVANCE AUTO PARTS INC
# ADVANCE AUTO PARTS INC
# 26
# ADVANCED MICRO DEVICES INC
# ADVANCED MICRO DEVICES INC
# ADVANCED MICRO DEVICES INC
# ADVANCED MICRO DEVICES INC
# ADVANCED MICRO DEVICES INC
# 16
# AES CORP
# AES CORP
# AES CORP
# AES CORP
# AES CORP
# 29
# AFLAC INC
# AFLAC INC
# AFLAC INC
# AFLAC INC
# AFLAC INC
# 25
# AGILENT TECHNOLOGIES, INC.
# AGILENT TECHNOLOGIES, INC.
# AGILENT TECHNOLOGIES, INC.
# AGILENT TECHNOLOGIES, INC.
# AGILENT TECHNOLOGIES, INC.
# 24
# AIR PRODUCTS & CHEMICALS INC /DE/
# AIR PRODUCTS & CHEMICALS INC /DE/
# AIR PRODUCTS & CHEMICALS INC /DE/
# AIR PRODUCTS & CHEMICALS INC /DE/
# AIR PRODUCTS & CHEMICALS INC /DE/
# 22
# AKAMAI TECHNOLOGIES INC
# AKAMAI TECHNOLOGIES INC
# AKAMAI TECHNOLOGIES INC
# AKAMAI TECHNOLOGIES INC
# AKAMAI TECHNOLOGIES INC
# 19
# ALASKA AIR GROUP, INC.
# ALASKA AIR GROUP, INC.
# ALASKA AIR GROUP, INC.
# ALASKA AIR GROUP, INC.
# ALASKA AIR GROUP, INC.
# 20
# ALBEMARLE CORP
# ALBEMARLE CORP
# ALBEMARLE CORP
# ALBEMARLE CORP
# ALBEMARLE CORP
# 29
# ALEXANDRIA REAL ESTATE EQUITIES, INC.
# ALEXANDRIA REAL ESTATE EQUITIES, INC.
# ALEXANDRIA REAL ESTATE EQUITIES, INC.
# ALEXANDRIA REAL ESTATE EQUITIES, INC.
# ALEXANDRIA REAL ESTATE EQUITIES, INC.
# 20
# ALEXION PHARMACEUTICALS, INC.
# ALEXION PHARMACEUTICALS, INC.
# ALEXION PHARMACEUTICALS, INC.
# ALEXION PHARMACEUTICALS, INC.
# ALEXION PHARMACEUTICALS, INC.
# 19
# ALIGN TECHNOLOGY INC
# ALIGN TECHNOLOGY INC
# ALIGN TECHNOLOGY INC
# ALIGN TECHNOLOGY INC
# CHIPOTLE MEXICAN GRILL INC
# CHIPOTLE MEXICAN GRILL INC
# CHIPOTLE MEXICAN GRILL INC
# 25
# Chubb Ltd
# Chubb Ltd
# Chubb Ltd
# Chubb Ltd
# Chubb Ltd
# 22
# CHURCH & DWIGHT CO INC /DE/
# CHURCH & DWIGHT CO INC /DE/
# CHURCH & DWIGHT CO INC /DE/
# CHURCH & DWIGHT CO INC /DE/
# CHURCH & DWIGHT CO INC /DE/
# 26
# CINCINNATI FINANCIAL CORP
# CINCINNATI FINANCIAL CORP
# CINCINNATI FINANCIAL CORP
# CINCINNATI FINANCIAL CORP
# CINCINNATI FINANCIAL CORP
# 18
# CINTAS CORP
# CINTAS CORP
# CINTAS CORP
# CINTAS CORP
# CINTAS CORP
# 18
# CISCO SYSTEMS, INC.
# CISCO SYSTEMS, INC.
# CISCO SYSTEMS, INC.
# CISCO SYSTEMS, INC.
# CISCO SYSTEMS, INC.
# 20
# CITIGROUP INC
# CITIGROUP INC
# CITIGROUP INC
# CITIGROUP INC
# CITIGROUP INC
# 23
# CITIZENS FINANCIAL GROUP INC/RI
# CITIZENS FINANCIAL GROUP INC/RI
# CITIZENS FINANCIAL GROUP INC/RI
# CITIZENS FINANCIAL GROUP INC/RI
# CITIZENS FINANCIAL GROUP INC/RI
# 21
# CITRIX SYSTEMS INC
# CITRIX SYSTEMS INC
# CITRIX SYSTEMS INC
# CITRIX SYSTEMS INC
# CITRIX SYSTEMS INC
# 19
# CME GROUP INC.
# CME GROUP INC.
# CME GROUP INC.
# CME GROUP INC.
# CME GROUP INC.
# 23
# CMS ENERGY CORP
# CMS ENERGY CORP
# CMS ENERGY CORP
# CMS ENERGY CORP
# CMS ENERGY CORP
# 17
# COCA COLA CO
# COCA COLA CO
# COCA COLA CO
# COCA COLA CO
# COCA COLA CO
# 21
# COGNIZANT TECHNOLOGY SOLUTIONS CORP
# COGNIZANT TECHNOLOGY SOLUTIONS CORP
# COGNIZANT TECHNOLOGY SOLUTIONS CORP
# COGNIZANT TECHNOLOGY SOLUTIONS CORP
# COGNIZANT TECHNOLOGY SOLUTIONS CORP
# 18
# COLGATE PALMOLIVE CO
# COLGATE PALMOLIVE CO
# COLGATE PALMOLIVE CO
# COLGATE PALMOLIVE CO
# COLGATE PALMOLIVE CO
# 17
# COMCAST CORP
# COMCAST CORP
# COMCAST CORP
# COMCAST CORP
# COMCAST CORP
# 24
# COMERICA INC /NEW/
# COMERICA INC /NEW/
# COMERICA INC /NEW/
# COMERICA INC /NEW/
# COMERICA INC /NEW/
# 24
# CONAGRA BRANDS INC.
# CONAGRA BRANDS INC.
# CONAGRA BRANDS INC.
# CONAGRA BRANDS INC.
# CONAGRA BRANDS INC.
# 17
# CONCHO RESOURCES INC
# CONCHO RESOURCES INC
# CONCHO RESOURCES INC
# CONCHO RESOURCES INC
# CONCHO RESOURCES INC
# 23
# CONOCOPHILLIPS
# CONOCOPHILLIPS
# CONOCOPHILLIPS
# CONOCOPHILLIPS
# CONOCOPHILLIPS
# FIFTH THIRD BANCORP
# FIFTH THIRD BANCORP
# FIFTH THIRD BANCORP
# 15
# FIRSTENERGY CORP
# FIRSTENERGY CORP
# FIRSTENERGY CORP
# FIRSTENERGY CORP
# FIRSTENERGY CORP
# 28
# FISERV INC
# FISERV INC
# FISERV INC
# FISERV INC
# FISERV INC
# 21
# FLEETCOR TECHNOLOGIES INC
# FLEETCOR TECHNOLOGIES INC
# FLEETCOR TECHNOLOGIES INC
# FLEETCOR TECHNOLOGIES INC
# FLEETCOR TECHNOLOGIES INC
# 18
# FLIR SYSTEMS INC
# FLIR SYSTEMS INC
# FLIR SYSTEMS INC
# FLIR SYSTEMS INC
# FLIR SYSTEMS INC
# 29
# FLOWSERVE CORP
# FLOWSERVE CORP
# FLOWSERVE CORP
# FLOWSERVE CORP
# FLOWSERVE CORP
# 27
# FMC CORP
# FMC CORP
# FMC CORP
# FMC CORP
# FMC CORP
# 21
# FORD MOTOR CO
# FORD MOTOR CO
# FORD MOTOR CO
# FORD MOTOR CO
# FORD MOTOR CO
# 15
# Fortinet, Inc.
# Fortinet, Inc.
# Fortinet, Inc.
# Fortinet, Inc.
# Fortinet, Inc.
# 19
# Fortune Brands Home & Security, Inc.
# Fortune Brands Home & Security, Inc.
# Fortune Brands Home & Security, Inc.
# Fortune Brands Home & Security, Inc.
# Fortune Brands Home & Security, Inc.
# 23
# FRANKLIN RESOURCES INC
# FRANKLIN RESOURCES INC
# FRANKLIN RESOURCES INC
# FRANKLIN RESOURCES INC
# FRANKLIN RESOURCES INC
# 16
# FREEPORT-MCMORAN INC
# FREEPORT-MCMORAN INC
# FREEPORT-MCMORAN INC
# FREEPORT-MCMORAN INC
# FREEPORT-MCMORAN INC
# 16
# GAP INC
# GAP INC
# GAP INC
# GAP INC
# GAP INC
# 18
# GARMIN LTD
# GARMIN LTD
# GARMIN LTD
# GARMIN LTD
# GARMIN LTD
# 16
# GARTNER INC
# GARTNER INC
# GARTNER INC
# GARTNER INC
# GARTNER INC
# 27
# GENERAL DYNAMICS CORP
# GENERAL DYNAMICS CORP
# GENERAL DYNAMICS CORP
# GENERAL DYNAMICS CORP
# GENERAL DYNAMICS CORP
# 15
# GENERAL ELECTRIC CO
# GENERAL ELECTRIC CO
# GENERAL ELECTRIC CO
# GENERAL ELECTRIC CO
# GENERAL ELECTRIC CO
# 19
# GENERAL MILLS INC
# GENERAL MILLS INC
# GENERAL MILLS INC
# GENERAL MILLS INC
# GENERAL MILLS INC
# 21
# General Motors Co
# General Motors Co
# General Motors Co
# General Motors Co
# General Motors Co
# 15
# GENUINE PARTS CO
# GENUINE PARTS CO
# GENUINE PARTS CO
# GENUINE PARTS CO
# GENUINE PARTS CO
# 26
# GILEAD SCIENCES INC
# GILEAD SCIENCES INC
# GILEAD SCIENCES INC
# GILEAD SCIENCES INC
# GILEAD SCIENCES INC
# 18
# GLOBAL PAYMENTS INC
# GLOBAL PAYMENTS INC
# GLOBAL PAYMENTS INC
# GLOBAL PAYMENTS INC
# GLOBAL PAYMENTS INC
# HORMEL FOODS CORP /DE/
# HORMEL FOODS CORP /DE/
# 19
# HOST HOTELS & RESORTS, INC.
# HOST HOTELS & RESORTS, INC.
# HOST HOTELS & RESORTS, INC.
# HOST HOTELS & RESORTS, INC.
# HOST HOTELS & RESORTS, INC.
# 15
# Howmet Aerospace Inc.
# Howmet Aerospace Inc.
# Howmet Aerospace Inc.
# Howmet Aerospace Inc.
# Howmet Aerospace Inc.
# 16
# HP INC
# HP INC
# HP INC
# HP INC
# HP INC
# 27
# HUMANA INC
# HUMANA INC
# HUMANA INC
# HUMANA INC
# HUMANA INC
# 27
# HUNTINGTON BANCSHARES INC/MD
# HUNTINGTON BANCSHARES INC/MD
# HUNTINGTON BANCSHARES INC/MD
# HUNTINGTON BANCSHARES INC/MD
# HUNTINGTON BANCSHARES INC/MD
# 18
# HUNTINGTON INGALLS INDUSTRIES, INC.
# HUNTINGTON INGALLS INDUSTRIES, INC.
# HUNTINGTON INGALLS INDUSTRIES, INC.
# HUNTINGTON INGALLS INDUSTRIES, INC.
# HUNTINGTON INGALLS INDUSTRIES, INC.
# 25
# IDEX CORP /DE/
# IDEX CORP /DE/
# IDEX CORP /DE/
# IDEX CORP /DE/
# IDEX CORP /DE/
# 21
# IDEXX LABORATORIES INC /DE
# IDEXX LABORATORIES INC /DE
# IDEXX LABORATORIES INC /DE
# IDEXX LABORATORIES INC /DE
# IDEXX LABORATORIES INC /DE
# 25
# ILLINOIS TOOL WORKS INC
# ILLINOIS TOOL WORKS INC
# ILLINOIS TOOL WORKS INC
# ILLINOIS TOOL WORKS INC
# ILLINOIS TOOL WORKS INC
# 26
# ILLUMINA, INC.
# ILLUMINA, INC.
# ILLUMINA, INC.
# ILLUMINA, INC.
# ILLUMINA, INC.
# 20
# INCYTE CORP
# INCYTE CORP
# INCYTE CORP
# INCYTE CORP
# INCYTE CORP
# 26
# INTEL CORP
# INTEL CORP
# INTEL CORP
# INTEL CORP
# INTEL CORP
# 30
# Intercontinental Exchange, Inc.
# Intercontinental Exchange, Inc.
# Intercontinental Exchange, Inc.
# Intercontinental Exchange, Inc.
# Intercontinental Exchange, Inc.
# 21
# INTERNATIONAL BUSINESS MACHINES CORP
# INTERNATIONAL BUSINESS MACHINES CORP
# INTERNATIONAL BUSINESS MACHINES CORP
# INTERNATIONAL BUSINESS MACHINES CORP
# INTERNATIONAL BUSINESS MACHINES CORP
# 15
# INTERNATIONAL PAPER CO /NEW/
# INTERNATIONAL PAPER CO /NEW/
# INTERNATIONAL PAPER CO /NEW/
# INTERNATIONAL PAPER CO /NEW/
# INTERNATIONAL PAPER CO /NEW/
# 23
# INTERPUBLIC GROUP OF COMPANIES, INC.
# INTERPUBLIC GROUP OF COMPANIES, INC.
# INTERPUBLIC GROUP OF COMPANIES, INC.
# INTERPUBLIC GROUP OF COMPANIES, INC.
# INTERPUBLIC GROUP OF COMPANIES, INC.
# 23
# INTERNATIONAL FLAVORS & FRAGRANCES INC
# INTERNATIONAL FLAVORS & FRAGRANCES INC
# INTERNATIONAL FLAVORS & FRAGRANCES INC
# INTERNATIONAL FLAVORS & FRAGRANCES INC
# INTERNATIONAL FLAVORS & FRAGRANCES INC
# 25
# INTUIT INC
# INTUIT INC
# INTUIT INC
# INTUIT INC
# INTUIT INC
# 19
# INTUITIVE SURGICAL INC
# INTUITIVE SURGICAL INC
# INTUITIVE SURGICAL INC
# INTUITIVE SURGICAL INC
# INTUITIVE SURGICAL INC
# 21
# Invesco Ltd.
# Invesco Ltd.
# Invesco Ltd.
# Invesco Ltd.
# Invesco Ltd.

# %%
#scraping the SEC for the 10-K of each company part 2
for name, cik in zip(df_sp_2['name_clean'], df_sp_2['cik']):
    company = Company(name, cik)
    docs = company.get_10Ks(no_of_documents=6)
    #appending a blank row because the latest 2020 report will not be used
    reports_10K.append('')
    reports_name.append(name)
    
    # generate a random sleep duration to look more 'natural'
    sleep_duration = random.randint(15,30)
    print(sleep_duration)
    time.sleep(sleep_duration) #program sleeps for the sleep_duration
    
    for doc in docs[1:]:
        text = TXTML.parse_full_10K(doc)    
        reports_10K.append(text)
        reports_name.append(name)
        print(name)
# Out:
# 17
# IPG PHOTONICS CORP
# IPG PHOTONICS CORP
# IPG PHOTONICS CORP
# IPG PHOTONICS CORP
# IPG PHOTONICS CORP
# 16
# IQVIA HOLDINGS INC.
# IQVIA HOLDINGS INC.
# IQVIA HOLDINGS INC.
# IQVIA HOLDINGS INC.
# IQVIA HOLDINGS INC.
# 25
# IRON MOUNTAIN INC
# IRON MOUNTAIN INC
# IRON MOUNTAIN INC
# IRON MOUNTAIN INC
# IRON MOUNTAIN INC
# 25
# HUNT J B TRANSPORT SERVICES INC
# HUNT J B TRANSPORT SERVICES INC
# HUNT J B TRANSPORT SERVICES INC
# HUNT J B TRANSPORT SERVICES INC
# HUNT J B TRANSPORT SERVICES INC
# 16
# HENRY JACK & ASSOCIATES INC
# HENRY JACK & ASSOCIATES INC
# HENRY JACK & ASSOCIATES INC
# HENRY JACK & ASSOCIATES INC
# HENRY JACK & ASSOCIATES INC
# 15
# JACOBS ENGINEERING GROUP INC /DE/
# JACOBS ENGINEERING GROUP INC /DE/
# JACOBS ENGINEERING GROUP INC /DE/
# JACOBS ENGINEERING GROUP INC /DE/
# JACOBS ENGINEERING GROUP INC /DE/
# 16
# J M SMUCKER Co
# J M SMUCKER Co
# J M SMUCKER Co
# J M SMUCKER Co
# J M SMUCKER Co
# 16
# JOHNSON & JOHNSON
# JOHNSON & JOHNSON
# JOHNSON & JOHNSON
# JOHNSON & JOHNSON
# JOHNSON & JOHNSON
# 29
# Johnson Controls International plc
# Johnson Controls International plc
# Johnson Controls International plc
# Johnson Controls International plc
# Johnson Controls International plc
# 27
# JPMORGAN CHASE & CO
# JPMORGAN CHASE & CO
# JPMORGAN CHASE & CO
# JPMORGAN CHASE & CO
# JPMORGAN CHASE & CO
# 23
# JUNIPER NETWORKS INC
# JUNIPER NETWORKS INC
# JUNIPER NETWORKS INC
# JUNIPER NETWORKS INC
# JUNIPER NETWORKS INC
# 23
# KANSAS CITY SOUTHERN
# KANSAS CITY SOUTHERN
# NetApp, Inc.
# NetApp, Inc.
# 15
# NETFLIX INC
# NETFLIX INC
# NETFLIX INC
# NETFLIX INC
# NETFLIX INC
# 15
# NEWELL BRANDS INC.
# NEWELL BRANDS INC.
# NEWELL BRANDS INC.
# NEWELL BRANDS INC.
# NEWELL BRANDS INC.
# 16
# NEWMONT Corp /DE/
# NEWMONT Corp /DE/
# NEWMONT Corp /DE/
# NEWMONT Corp /DE/
# NEWMONT Corp /DE/
# 17
# NEWS CORP
# NEWS CORP
# NEWS CORP
# NEWS CORP
# NEWS CORP
# 16
# NEXTERA ENERGY INC
# NEXTERA ENERGY INC
# NEXTERA ENERGY INC
# NEXTERA ENERGY INC
# NEXTERA ENERGY INC
# 20
# Nielsen Holdings plc
# Nielsen Holdings plc
# Nielsen Holdings plc
# Nielsen Holdings plc
# Nielsen Holdings plc
# 18
# NIKE, Inc.
# NIKE, Inc.
# NIKE, Inc.
# NIKE, Inc.
# NIKE, Inc.
# 18
# NISOURCE INC.
# NISOURCE INC.
# NISOURCE INC.
# NISOURCE INC.
# NISOURCE INC.
# 19
# NOBLE ENERGY INC
# NOBLE ENERGY INC
# NOBLE ENERGY INC
# NOBLE ENERGY INC
# NOBLE ENERGY INC
# 27
# NORDSTROM INC
# NORDSTROM INC
# NORDSTROM INC
# NORDSTROM INC
# NORDSTROM INC
# 28
# NORFOLK SOUTHERN CORP
# NORFOLK SOUTHERN CORP
# NORFOLK SOUTHERN CORP
# NORFOLK SOUTHERN CORP
# NORFOLK SOUTHERN CORP
# 28
# NORTHERN TRUST CORP
# NORTHERN TRUST CORP
# NORTHERN TRUST CORP
# NORTHERN TRUST CORP
# NORTHERN TRUST CORP
# 19
# NORTHROP GRUMMAN CORP /DE/
# NORTHROP GRUMMAN CORP /DE/
# NORTHROP GRUMMAN CORP /DE/
# NORTHROP GRUMMAN CORP /DE/
# NORTHROP GRUMMAN CORP /DE/
# 20
# NortonLifeLock Inc.
# NortonLifeLock Inc.
# NortonLifeLock Inc.
# NortonLifeLock Inc.
# NortonLifeLock Inc.
# 26
# Norwegian Cruise Line Holdings Ltd.
# Norwegian Cruise Line Holdings Ltd.
# Norwegian Cruise Line Holdings Ltd.
# Norwegian Cruise Line Holdings Ltd.
# Norwegian Cruise Line Holdings Ltd.
# 19
# NRG ENERGY, INC.
# NRG ENERGY, INC.
# NRG ENERGY, INC.
# NRG ENERGY, INC.
# NRG ENERGY, INC.
# 23
# NUCOR CORP
# NUCOR CORP
# NUCOR CORP
# NUCOR CORP
# NUCOR CORP
# 15
# NVIDIA CORP
# NVIDIA CORP
# NVIDIA CORP
# NVIDIA CORP
# NVIDIA CORP
# 16
# NVR INC
# NVR INC
# NVR INC
# NVR INC
# NVR INC
# 29
# O REILLY AUTOMOTIVE INC
# O REILLY AUTOMOTIVE INC
# O REILLY AUTOMOTIVE INC
# O REILLY AUTOMOTIVE INC
# O REILLY AUTOMOTIVE INC
# 26
# OCCIDENTAL PETROLEUM CORP /DE/
# OCCIDENTAL PETROLEUM CORP /DE/
# OCCIDENTAL PETROLEUM CORP /DE/
# OCCIDENTAL PETROLEUM CORP /DE/
# OCCIDENTAL PETROLEUM CORP /DE/
# 20
# OLD DOMINION FREIGHT LINE, INC.
# OLD DOMINION FREIGHT LINE, INC.
# OLD DOMINION FREIGHT LINE, INC.
# OLD DOMINION FREIGHT LINE, INC.
# OLD DOMINION FREIGHT LINE, INC.
# 20
# OMNICOM GROUP INC.
# OMNICOM GROUP INC.
# OMNICOM GROUP INC.
# OMNICOM GROUP INC.
# OMNICOM GROUP INC.
# 18
# ONEOK INC /NEW/
# ONEOK INC /NEW/
# ONEOK INC /NEW/
# ONEOK INC /NEW/
# ONEOK INC /NEW/
# 23
# ORACLE CORP
# ORACLE CORP
# ORACLE CORP
# ORACLE CORP
# ORACLE CORP
# 15
# PACCAR INC
# PACCAR INC
# PACCAR INC
# PACCAR INC
# PACCAR INC
# 23
# PACKAGING CORP OF AMERICA
# PACKAGING CORP OF AMERICA
# PACKAGING CORP OF AMERICA
# PACKAGING CORP OF AMERICA
# PACKAGING CORP OF AMERICA
# 16
# PARKER HANNIFIN CORP
# PARKER HANNIFIN CORP
# PARKER HANNIFIN CORP
# PARKER HANNIFIN CORP
# PARKER HANNIFIN CORP
# 21
# PAYCHEX INC
# PAYCHEX INC
# PAYCHEX INC
# PAYCHEX INC
# PAYCHEX INC
# 18
# Paycom Software, Inc.
# Paycom Software, Inc.
# Paycom Software, Inc.
# Paycom Software, Inc.
# Paycom Software, Inc.
# 21
# PENTAIR plc
# PENTAIR plc
# PENTAIR plc
# PENTAIR plc
# PENTAIR plc
# 30
# People's United Financial, Inc.
# People's United Financial, Inc.
# People's United Financial, Inc.
# People's United Financial, Inc.
# People's United Financial, Inc.
# 29
# PEPSICO INC
# PEPSICO INC
# PEPSICO INC
# PEPSICO INC
# PEPSICO INC
# 19
# PERKINELMER INC
# PERKINELMER INC
# PERKINELMER INC
# PERKINELMER INC
# PERKINELMER INC
# 15
# PERRIGO Co plc
# PERRIGO Co plc
# PERRIGO Co plc
# PERRIGO Co plc
# PERRIGO Co plc
# 15
# PFIZER INC
# PFIZER INC
# PFIZER INC
# PFIZER INC
# PFIZER INC
# 29
# Philip Morris International Inc.
# Philip Morris International Inc.
# Philip Morris International Inc.
# Philip Morris International Inc.
# Philip Morris International Inc.
# 20
# Phillips 66
# Phillips 66
# Phillips 66
# Phillips 66
# Phillips 66
# 15
# PINNACLE WEST CAPITAL CORP
# PINNACLE WEST CAPITAL CORP
# PINNACLE WEST CAPITAL CORP
# PINNACLE WEST CAPITAL CORP
# PINNACLE WEST CAPITAL CORP
# 30
# PIONEER NATURAL RESOURCES CO
# PIONEER NATURAL RESOURCES CO
# PIONEER NATURAL RESOURCES CO
# PIONEER NATURAL RESOURCES CO
# PIONEER NATURAL RESOURCES CO
# 19
# PNC FINANCIAL SERVICES GROUP, INC.
# PNC FINANCIAL SERVICES GROUP, INC.
# PNC FINANCIAL SERVICES GROUP, INC.
# PNC FINANCIAL SERVICES GROUP, INC.
# SEALED AIR CORP/DE
# 15
# SEMPRA ENERGY
# SEMPRA ENERGY
# SEMPRA ENERGY
# SEMPRA ENERGY
# SEMPRA ENERGY
# 27
# ServiceNow, Inc.
# ServiceNow, Inc.
# ServiceNow, Inc.
# ServiceNow, Inc.
# ServiceNow, Inc.
# 22
# SHERWIN WILLIAMS CO
# SHERWIN WILLIAMS CO
# SHERWIN WILLIAMS CO
# SHERWIN WILLIAMS CO
# SHERWIN WILLIAMS CO
# 29
# SIMON PROPERTY GROUP INC /DE/
# SIMON PROPERTY GROUP INC /DE/
# SIMON PROPERTY GROUP INC /DE/
# SIMON PROPERTY GROUP INC /DE/
# SIMON PROPERTY GROUP INC /DE/
# 30
# SKYWORKS SOLUTIONS, INC.
# SKYWORKS SOLUTIONS, INC.
# SKYWORKS SOLUTIONS, INC.
# SKYWORKS SOLUTIONS, INC.
# SKYWORKS SOLUTIONS, INC.
# 20
# SL GREEN REALTY CORP
# SL GREEN REALTY CORP
# SL GREEN REALTY CORP
# SL GREEN REALTY CORP
# SL GREEN REALTY CORP
# 21
# Snap-on Inc
# Snap-on Inc
# Snap-on Inc
# Snap-on Inc
# Snap-on Inc
# 22
# SOUTHERN CO
# SOUTHERN CO
# SOUTHERN CO
# SOUTHERN CO
# SOUTHERN CO
# 25
# SOUTHWEST AIRLINES CO
# SOUTHWEST AIRLINES CO
# SOUTHWEST AIRLINES CO
# SOUTHWEST AIRLINES CO
# SOUTHWEST AIRLINES CO
# 17
# STANLEY BLACK & DECKER, INC.
# STANLEY BLACK & DECKER, INC.
# STANLEY BLACK & DECKER, INC.
# STANLEY BLACK & DECKER, INC.
# STANLEY BLACK & DECKER, INC.
# 24
# STARBUCKS CORP
# STARBUCKS CORP
# STARBUCKS CORP
# STARBUCKS CORP
# STARBUCKS CORP
# 24
# STATE STREET CORP
# STATE STREET CORP
# STATE STREET CORP
# STATE STREET CORP
# STATE STREET CORP
# 27
# STRYKER CORP
# STRYKER CORP
# STRYKER CORP
# STRYKER CORP
# STRYKER CORP
# 18
# SVB FINANCIAL GROUP
# SVB FINANCIAL GROUP
# SVB FINANCIAL GROUP
# SVB FINANCIAL GROUP
# SVB FINANCIAL GROUP
# 23
# Synchrony Financial
# Synchrony Financial
# Synchrony Financial
# Synchrony Financial
# Synchrony Financial
# 23
# SYNOPSYS INC
# SYNOPSYS INC
# SYNOPSYS INC
# SYNOPSYS INC
# SYNOPSYS INC
# 24
# SYSCO CORP
# SYSCO CORP
# SYSCO CORP
# SYSCO CORP
# SYSCO CORP
# 27
# T-Mobile US, Inc.
# T-Mobile US, Inc.
# T-Mobile US, Inc.
# T-Mobile US, Inc.
# T-Mobile US, Inc.
# 19
# PRICE T ROWE GROUP INC
# PRICE T ROWE GROUP INC
# PRICE T ROWE GROUP INC
# PRICE T ROWE GROUP INC
# PRICE T ROWE GROUP INC
# 25
# TAKE TWO INTERACTIVE SOFTWARE INC
# TAKE TWO INTERACTIVE SOFTWARE INC
# TAKE TWO INTERACTIVE SOFTWARE INC
# WILLIS TOWERS WATSON PLC
# 29
# WYNN RESORTS LTD
# WYNN RESORTS LTD
# WYNN RESORTS LTD
# WYNN RESORTS LTD
# WYNN RESORTS LTD
# 21
# XCEL ENERGY INC
# XCEL ENERGY INC
# XCEL ENERGY INC
# XCEL ENERGY INC
# XCEL ENERGY INC
# 23
# XILINX INC
# XILINX INC
# XILINX INC
# XILINX INC
# XILINX INC
# 25
# Xylem Inc.
# Xylem Inc.
# Xylem Inc.
# Xylem Inc.
# Xylem Inc.
# 26
# YUM BRANDS INC
# YUM BRANDS INC
# YUM BRANDS INC
# YUM BRANDS INC
# YUM BRANDS INC
# 22
# ZEBRA TECHNOLOGIES CORP
# ZEBRA TECHNOLOGIES CORP
# ZEBRA TECHNOLOGIES CORP
# ZEBRA TECHNOLOGIES CORP
# ZEBRA TECHNOLOGIES CORP
# 18
# ZIMMER BIOMET HOLDINGS, INC.
# ZIMMER BIOMET HOLDINGS, INC.
# ZIMMER BIOMET HOLDINGS, INC.
# ZIMMER BIOMET HOLDINGS, INC.
# ZIMMER BIOMET HOLDINGS, INC.
# 17
# ZIONS BANCORPORATION, NATIONAL ASSOCIATION /UT/
# ZIONS BANCORPORATION, NATIONAL ASSOCIATION /UT/
# ZIONS BANCORPORATION, NATIONAL ASSOCIATION /UT/
# ZIONS BANCORPORATION, NATIONAL ASSOCIATION /UT/
# ZIONS BANCORPORATION, NATIONAL ASSOCIATION /UT/
# 26
# Zoetis Inc.
# Zoetis Inc.
# Zoetis Inc.
# Zoetis Inc.
# Zoetis Inc.

# %%
len(reports_name)
# Out:
# 2808

# %%
# Cleaning the reports
reports_10K = [x.replace('\t','').replace('\n','').replace('\xa0','').replace('x97', '') for x in reports_10K]

# %%
pd.DataFrame(reports_name).to_csv('./datasets/reports_name.csv')

# %%
pd.DataFrame(reports_10K).to_csv('./datasets/reports_10K.csv')

# %%
# creating a new df
df = pd.DataFrame(reports_name, columns=['name'])
df['ticker'] = ticker
df['dates'] = dates

# %%
df['dates'] = pd.to_datetime(df['dates'].astype('str'))

# %%
df.head(50)
# Out:
#                          name ticker      dates
# 0                       3M CO    MMM 2020-02-06
# 1                       3M CO    MMM 2019-02-07
# 2                       3M CO    MMM 2018-02-08
# 3                       3M CO    MMM 2017-02-09
# 4                       3M CO    MMM 2016-02-11
# 5                       3M CO    MMM 2015-02-12
# 6              SMITH A O CORP    AOS 2020-02-24
# 7              SMITH A O CORP    AOS 2019-02-15
# 8              SMITH A O CORP    AOS 2018-02-16
# 9              SMITH A O CORP    AOS 2017-02-17
# 10             SMITH A O CORP    AOS 2016-02-17
# 11             SMITH A O CORP    AOS 2015-02-17
# 12        ABBOTT LABORATORIES    ABT 2020-02-21
# 13        ABBOTT LABORATORIES    ABT 2019-02-22
# 14        ABBOTT LABORATORIES    ABT 2018-02-16
# 15        ABBOTT LABORATORIES    ABT 2017-02-17
# 16        ABBOTT LABORATORIES    ABT 2016-02-19
# 17        ABBOTT LABORATORIES    ABT 2015-02-27
# 18                AbbVie Inc.   ABBV 2020-02-21
# 19                AbbVie Inc.   ABBV 2019-02-27
# 20                AbbVie Inc.   ABBV 2018-02-16
# 21                AbbVie Inc.   ABBV 2017-02-17
# 22                AbbVie Inc.   ABBV 2016-02-19
# 23                AbbVie Inc.   ABBV 2015-02-20
# 24                ABIOMED INC   ABMD 2020-05-21
# 25                ABIOMED INC   ABMD 2019-05-23
# 26                ABIOMED INC   ABMD 2018-05-24
# 27                ABIOMED INC   ABMD 2017-05-25
# 28                ABIOMED INC   ABMD 2016-05-26
# 29                ABIOMED INC   ABMD 2015-05-28
# 30              Accenture plc    ACN 2019-10-29
# 31              Accenture plc    ACN 2018-10-24
# 32              Accenture plc    ACN 2017-10-26
# 33              Accenture plc    ACN 2016-10-28
# 34              Accenture plc    ACN 2015-10-30
# 35              Accenture plc    ACN 2014-10-24
# 36  Activision Blizzard, Inc.   ATVI 2020-02-27
# 37  Activision Blizzard, Inc.   ATVI 2019-02-28
# 38  Activision Blizzard, Inc.   ATVI 2018-02-27
# 39  Activision Blizzard, Inc.   ATVI 2017-02-28
# 40  Activision Blizzard, Inc.   ATVI 2016-02-29
# 41  Activision Blizzard, Inc.   ATVI 2015-02-26
# 42                 ADOBE INC.   ADBE 2020-01-21
# 43                 ADOBE INC.   ADBE 2019-01-25
# 44                 ADOBE INC.   ADBE 2018-01-22
# 45                 ADOBE INC.   ADBE 2017-01-20
# 46                 ADOBE INC.   ADBE 2016-01-19
# 47                 ADOBE INC.   ADBE 2015-01-20
# 48     ADVANCE AUTO PARTS INC    AAP 2020-02-18
# 49     ADVANCE AUTO PARTS INC    AAP 2019-02-19

# %% [markdown]
# ## Scraping Stock price from Yahoo Finance

# %%
# getting the closing price on the day of annual report release
price_on_date = []

for ticker, dates in zip(df['ticker'], df['dates']):
    offset = timedelta(days=1)
    try:
        price_on_date.append(yf.Ticker(ticker).history(start=str(dates.date()), 
                                              end=str((dates.date()+offset)))['Close'][dates.date()])
    except:
        price_on_date.append(np.NaN)
        pass
# Out:
# - HWM: No data found for this date range, symbol may be delisted
# - HWM: No data found for this date range, symbol may be delisted
# - HWM: No data found for this date range, symbol may be delisted
# - HWM: No data found for this date range, symbol may be delisted
# - HWM: No data found for this date range, symbol may be delisted
# - NLOK: No data found for this date range, symbol may be delisted
# - NLOK: No data found for this date range, symbol may be delisted
# - TT: No data found for this date range, symbol may be delisted
# - TT: No data found for this date range, symbol may be delisted
# - TT: No data found for this date range, symbol may be delisted

# %%
# getting the closing price on the day of annual report release
sp_on_date = []
for dates in df['dates']:
    offset = timedelta(days=1)
    try:
        sp_on_date.append(yf.Ticker('^GSPC').history(start=str(dates.date()+offset), 
                                              end=str(dates.date()+offset))['Close'][dates])
    except:
        sp_on_date.append(np.NaN)
        pass
# Out:
# - ^GSPC: No data found for this date range, symbol may be delisted
# - ^GSPC: No data found for this date range, symbol may be delisted
# - ^GSPC: No data found for this date range, symbol may be delisted
# - ^GSPC: No data found for this date range, symbol may be delisted

# %%
print(len(price_on_date))
print(len(sp_on_date))
# Out:
# 2808
# 2808

# %% [markdown]
# ## Compiling into a dataframe

# %%
#creating new columns
df['price_on_date'] = price_on_date

# creating columns of difference in stock price
# from date of 1 annual report to the next
df['price_change_next_yr'] = df['price_on_date'].diff()*(-1)
df['price_change_next_yr'][::6] = np.NaN

df['sp_on_date'] = sp_on_date

# creating columns of difference in S&P Index price
# from date of 1 annual report to the next
df['sp_price_change_next_year'] = df['sp_on_date'].diff()*(-1)
df['sp_price_change_next_year'][::6] = np.NaN
# Out:
# C:\Users\russ\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\russ\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['reports'] = reports_10K

# %%
#checking the newly appeneded columns
df.isnull().sum()
# Out:
# name                           0
# ticker                         0
# dates                          0
# price_on_date                 14
# price_change_next_yr         488
# sp_on_date                     4
# sp_price_change_next_year    476
# reports                        0
# dtype: int64

# %%
df.describe()
# Out:
#        price_on_date  price_change_next_yr   sp_on_date  \
# count    2794.000000           2320.000000  2804.000000
# mean      103.228114             12.712384  2515.896958
# std       175.135896             55.290577   431.676773
# min      -436.160000           -459.210000  1829.080000
# 25%        41.392500             -2.832500  2109.660000
# 50%        67.315000              5.905000  2545.940000
# 75%       112.385000             18.400000  2784.490000
# max      3965.950000           1365.150000  3386.150000
#
#        sp_price_change_next_year
# count                2332.000000
# mean                  218.067719
# std                   248.793395
# min                  -691.650000
# 25%                    44.220000
# 50%                   284.580000
# 75%                   415.590000
# max                   804.600000

# %%
df.head(10)
# Out:
#              name ticker      dates  price_on_date  price_change_next_yr  \
# 0           3M CO    MMM 2020-02-06         159.84                   NaN
# 1           3M CO    MMM 2019-02-07         189.71                -29.87
# 2           3M CO    MMM 2018-02-08         206.12                -16.41
# 3           3M CO    MMM 2017-02-09         161.00                 45.12
# 4           3M CO    MMM 2016-02-11         133.54                 27.46
# 5           3M CO    MMM 2015-02-12         143.14                 -9.60
# 6  SMITH A O CORP    AOS 2020-02-24          42.60                   NaN
# 7  SMITH A O CORP    AOS 2019-02-15          50.37                 -7.77
# 8  SMITH A O CORP    AOS 2018-02-16          62.93                -12.56
# 9  SMITH A O CORP    AOS 2017-02-17          47.13                 15.80
#
#    sp_on_date  sp_price_change_next_year  \
# 0     3345.78                        NaN
# 1     2706.05                     639.73
# 2     2581.00                     125.05
# 3     2307.87                     273.13
# 4     1829.08                     478.79
# 5     2088.48                    -259.40
# 6     3225.89                        NaN
# 7     2775.60                     450.29
# 8     2732.22                      43.38
# 9     2351.16                     381.06
#
#                                              reports
# 0
# 1  mmm_Current_Folio_10KlowUNITED STATESSECURITIE...
# 2  mmm_Current_Folio_10KTable of ContentslowUNITE...
# 3  mmm_Current_Folio_10KTable of ContentslowUNITE...
# 4  mmm_Current_Folio_10KTable of ContentslowUNITE...
# 5    Table of ContentsUNITED STATESSECURITIES AND...
# 6
# 7  Form 10-K Table of Contents  UNITED STATES SEC...
# 8  Form 10-K Table of Contents  UNITED STATES SEC...
# 9  Form 10-K Table of Contents  UNITED STATES SEC...

# %%
df.shape
# Out:
# (2808, 8)

# %%
df.to_csv('./datasets/df.csv', index=False)
